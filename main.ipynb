# %% [markdown]
# # Experiments

# %% [markdown]
# ## Contents
# - [1. Replicate DeepFish benchmark](#1.-Replicate-DeepFish-benchmark)
# - [2. Test active learning strategies without domain adaptation](#2.-Test-active-learning-strategies-without-domain-adaptation)
#     - [Random](#Random)
#     - [Learned loss](#Learned-loss)
# - [3. Test domain adaptation without active learning](#3.-Test-domain-adaptation)
# - [4. Test domain adaptation with active learning](#4.-Test-domain-adaptation-with-active-learning)

# %% [markdown]
# # 1. Replicate DeepFish benchmark

# %%
# Replicate results in 20 epochs
# !python trainval.py -e seg -sb ./results/segmentation -d ./data/Segmentation/ -r 1 -da 0 -ss None -n 310 -ne 15

# %% [markdown]
# # 2. Test active learning strategies without domain adaptation

# %% [markdown]
# ####  Note: each experiment is repeated 5x

# %% [markdown]
# ## Random

# %%
# 10 samples
# !python trainval.py -e seg -sb ./results/active_learning/random10 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  2.01it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.25it/s]
# 0 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# 10 samples
# !python trainval.py -e seg -sb ./results/active_learning/random10 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  1.69it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:15<00:00,  4.11it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0              0.0358      0.494643
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 10 samples
# !python trainval.py -e seg -sb ./results/active_learning/random10 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  1.99it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.33it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0              0.0358      0.494643
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 10 samples
# !python trainval.py -e seg -sb ./results/active_learning/random10 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  1.97it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.28it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0              0.0358      0.494644
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 10 samples
# !python trainval.py -e seg -sb ./results/active_learning/random10 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  2.00it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.21it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.035801      0.494643
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/random10/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 20 samples
# !python trainval.py -e seg -sb ./results/active_learning/random20 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.61it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.30it/s]
# 0 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# 20 samples
# !python trainval.py -e seg -sb ./results/active_learning/random20 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.68it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.23it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.021081       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 20 samples
# !python trainval.py -e seg -sb ./results/active_learning/random20 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.66it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.18it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.021078       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 20 samples
# !python trainval.py -e seg -sb ./results/active_learning/random20 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.66it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.33it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.021082       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 20 samples
# !python trainval.py -e seg -sb ./results/active_learning/random20 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.58it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.20it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.021082       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/random20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 40 samples
# !python trainval.py -e seg -sb ./results/active_learning/random40 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.16it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.31it/s]
# 0 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# 40 samples
# !python trainval.py -e seg -sb ./results/active_learning/random40 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.19it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.33it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.048657      0.504089
# ...

# %%
# 40 samples
# !python trainval.py -e seg -sb ./results/active_learning/random40 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.19it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.33it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.048663      0.504057
# ...

# %%
# 40 samples
# !python trainval.py -e seg -sb ./results/active_learning/random40 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.23it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.36it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.048679      0.504041
# ...

# %%
# 40 samples
# !python trainval.py -e seg -sb ./results/active_learning/random40 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.15it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.40it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.048688      0.504084
# ...

# %%
# 80 samples
# !python trainval.py -e seg -sb ./results/active_learning/random80 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58]
# Training
# 100%|███████████████████████████████████████████| 40/40 [00:11<00:00,  3.54it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.17it/s]
# ...

# %%
# 80 samples
# !python trainval.py -e seg -sb ./results/active_learning/random80 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58]
# Training
# 100%|███████████████████████████████████████████| 40/40 [00:11<00:00,  3.57it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.43it/s]
# ...

# %%
# 80 samples
# !python trainval.py -e seg -sb ./results/active_learning/random80 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58]
# Training
# 100%|███████████████████████████████████████████| 40/40 [00:11<00:00,  3.57it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.39it/s]
# ...

# %%
# 80 samples
# !python trainval.py -e seg -sb ./results/active_learning/random80 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58]
# Training
# 100%|███████████████████████████████████████████| 40/40 [00:11<00:00,  3.56it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.35it/s]
# ...

# %%
# 80 samples
# !python trainval.py -e seg -sb ./results/active_learning/random80 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58]
# Training
# 100%|███████████████████████████████████████████| 40/40 [00:11<00:00,  3.58it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.24it/s]
# ...

# %%
# 120 samples
# !python trainval.py -e seg -sb ./results/active_learning/random120 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13]
# Training
# ...

# %%
# 120 samples
# !python trainval.py -e seg -sb ./results/active_learning/random120 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13]
# Training
# ...

# %%
# 120 samples
# !python trainval.py -e seg -sb ./results/active_learning/random120 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13]
# Training
# ...

# %%
# 120 samples
# !python trainval.py -e seg -sb ./results/active_learning/random120 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13]
# Training
# ...

# %%
# 120 samples
# !python trainval.py -e seg -sb ./results/active_learning/random120 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13]
# Training
# ...

# %%
# 160 samples
# !python trainval.py -e seg -sb ./results/active_learning/random160 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 160 samples
# !python trainval.py -e seg -sb ./results/active_learning/random160 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 160 samples
# !python trainval.py -e seg -sb ./results/active_learning/random160 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 160 samples
# !python trainval.py -e seg -sb ./results/active_learning/random160 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 160 samples
# !python trainval.py -e seg -sb ./results/active_learning/random160 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 200 samples
# !python trainval.py -e seg -sb ./results/active_learning/random200 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 200 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  200
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 200 samples
# !python trainval.py -e seg -sb ./results/active_learning/random200 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 200 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  200
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 200 samples
# !python trainval.py -e seg -sb ./results/active_learning/random200 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 200 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  200
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 200 samples
# !python trainval.py -e seg -sb ./results/active_learning/random200 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 200 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  200
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %%
# 200 samples
# !python trainval.py -e seg -sb ./results/active_learning/random200 -d ./data/Segmentation/ -r 1 -da 0 -ss random -n 200 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/random200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  200
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88 242 254 279 219   3 161 304 220 270 264  10 190 257 154
#  212  31   8 170 120  46 109 146 248 295  74 198 247  68  42   9  33 271
#  206  92  89 239  66 168 160  58 249 172 213  14 164 307 245 298 214 106
#  305 107 103 123 227   4   1 191  16  94 181 171  15 162 202  43 151 300
#  193  54  11 246  73 253 136 135 284 244  17  13 299  51 302   6 110 195
# ...

# %% [markdown]
# ## Learned loss

# %%
# 20 samples (10 random, 10 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_20 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  1.96it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.25it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.133873      0.494643
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 20 samples (10 random, 10 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_20 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  2.02it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.32it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.133873      0.494643
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 20 samples (10 random, 10 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_20 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  2.01it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.24it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.133873      0.494643
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 20 samples (10 random, 10 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_20 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  2.02it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.16it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.133873      0.494643
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 20 samples (10 random, 10 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_20 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 10 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  10
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  1.97it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.40it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.133873      0.494643
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_20/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# [290 128 116 252 272 108 155 218 167 282]
# Training
# ...

# %%
# 40 samples (20 random, 20 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_40 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:04<00:00,  2.48it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.22it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.119725       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 40 samples (20 random, 20 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_40 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.69it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.40it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.119726       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 40 samples (20 random, 20 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_40 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.69it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.29it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.119722       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 40 samples (20 random, 20 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_40 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.69it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.35it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.119727       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 40 samples (20 random, 20 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_40 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 20 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  20
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185]
# Training
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.66it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.25it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.119727       0.48978
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_40/e3666ff88d51e5edbb790ff8af6d89e0
# random!
# ...

# %%
# 80 samples (40 random, 40 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_80 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.01it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.20it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147992      0.504084
# ...

# %%
# 80 samples (40 random, 40 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_80 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.24it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.28it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.148026      0.504089
# ...

# %%
# 80 samples (40 random, 40 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_80 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.02it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.37it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147985      0.504041
# ...

# %%
# 80 samples (40 random, 40 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_80 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.26it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.39it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0             0.14801      0.504073
# ...

# %%
# 80 samples (40 random, 40 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_80 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 40 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_80/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  40
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.24it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:13<00:00,  4.44it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147999      0.504044
# ...

# %%
# 120 samples (40 random, 80 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_120 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.21it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.37it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.148024      0.504064
# ...

# %%
# 120 samples (40 random, 80 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_120 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.26it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.38it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.148007      0.504041
# ...

# %%
# 120 samples (40 random, 80 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_120 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.27it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.25it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.148067      0.504051
# ...

# %%
# 120 samples (40 random, 80 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_120 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.24it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.42it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147993      0.504056
# ...

# %%
# 120 samples (40 random, 80 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_120 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 80 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_120/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  80
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.23it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.40it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.148007      0.504084
# ...

# %%
# 160 samples (40 random, 120 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_160 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.06it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:15<00:00,  4.09it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.148052      0.504105
# ...

# %%
# 160 samples (40 random, 120 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_160 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.25it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.37it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147998      0.504064
# ...

# %%
# 160 samples (40 random, 120 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_160 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 120 -ne 10
# Out:
# 100%|███████████████████████████████████████████| 80/80 [00:20<00:00,  3.93it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:13<00:00,  4.54it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147987      0.504055
# 1      1            0.132324      0.605909
# 2      2            0.119571      0.679220
# 3      3            0.109158      0.734270
# 4      4            0.107232      0.818650
# Saved in /global/u2/s/saksman/DeepFish/results/active_learning/ll_160/e3666ff88d51e5edbb790ff8af6d89e0
# active learning after epoch #4!
# ...

# %%
# 160 samples (40 random, 120 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_160 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.22it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.30it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147979      0.504046
# ...

# %%
# 160 samples (40 random, 120 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_160 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 120 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_160/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  120
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.26it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.39it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147964        0.5041
# ...

# %%
# 200 samples (40 random, 160 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_200 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.07it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:15<00:00,  4.12it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147994      0.504046
# ...

# %%
# 200 samples (40 random, 160 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_200 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.23it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.38it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.148003      0.504065
# ...

# %%
# 200 samples (40 random, 160 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_200 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:07<00:00,  2.76it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.31it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0               0.148      0.504047
# ...

# %%
# 200 samples (40 random, 160 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_200 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.17it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:14<00:00,  4.15it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147954      0.504072
# ...

# %%
# 200 samples (40 random, 160 learned)
# !python trainval.py -e seg -sb ./results/active_learning/ll_200 -d ./data/Segmentation/ -r 1 -da 0 -ss learned_loss -n 160 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_learning/ll_200/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  learned_loss
# # samples:  160
# random!
# [290 128 116 252 272 108 155 218 167 282 251 268  70 112 111  85 127 260
#  226 185  27  71   0  19 182  84  83  25  55 177  35 169 277  97 197 273
#  142 183  24  88]
# Training
# 100%|███████████████████████████████████████████| 20/20 [00:06<00:00,  3.23it/s]
# Validating
# 100%|███████████████████████████████████████████| 62/62 [00:13<00:00,  4.44it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.147987      0.504091
# ...

# %% [markdown]
# ## Plot results across experiments

# %%
# with fixed # epochs
import matplotlib.pyplot as plt
import numpy as np

random_10 = np.mean(np.array([0.588, 0.588, 0.588, 0.588, 0.588]))
random_20 = np.mean(np.array([0.665, 0.665, 0.665, 0.665, 0.665]))
random_40 = np.mean(np.array([0.789, 0.785, 0.787, 0.789, 0.787]))
random_80 = np.mean(np.array([0.729, 0.742, 0.732, 0.724, 0.730]))
random_120 = np.mean(np.array([0.848, 0.851, 0.85, 0.85, 0.851]))
random_160 = np.mean(np.array([0.862, 0.868, 0.87, 0.866, 0.876]))
random_200 = np.mean(np.array([0.871, 0.871, 0.872, 0.872, 0.872]))

ll_20 = np.mean(np.array([0.621, 0.621, 0.621, 0.621, 0.621]))
ll_40 = np.mean(np.array([0.598, 0.594, 0.591, 0.594, 0.596]))
ll_80 = np.mean(np.array([0.807, 0.72, 0.813, 0.814, 0.806]))
ll_120 = np.mean(np.array([0.833, 0.837, 0.787, 0.804, 0.835]))
ll_160 = np.mean(np.array([0.823, 0.862, 0.857, 0.848, 0.863]))
ll_200 = np.mean(np.array([0.865, 0.864, 0.867, 0.868, 0.865]))


random = {
0: 0, 
10: random_10, 
20: random_20, 
40: random_40, 
80: random_80, 
120: random_120,
160: random_160,
200: random_200}
random_list = sorted(random.items()) # sorted by key, return a list of tuples

ll = {
20: ll_20, 
40: ll_40, 
80: ll_80, 
120: ll_120,
160: ll_160,
200: ll_200}

ll_list = sorted(ll.items()) # sorted by key, return a list of tuples

plt.clf()
x1, y1 = zip(*random_list) # unpack a list of pairs into two tuples
x2, y2 = zip(*ll_list) # unpack a list of pairs into two tuples
# plt.ylim(0, 100)
plt.plot(x1, y1, '--bo', label="random")
plt.plot(x2, y2, '--go', label="LL4AL")
plt.legend(loc='lower right')
plt.title('')
plt.xlabel('# Training Labels')
plt.ylabel('Validation mIoU')
plt.savefig('/global/u2/s/saksman/DeepFish/results/active_learning/al_perf_plot.png')
plt.show()

# %% [markdown]
# # Domain adaptation v. no domain adaptation test

# %%
# Create training / testing split for domain adaptation
from sklearn.model_selection import train_test_split
import pandas as pd 
import numpy
import csv

with open("/global/u2/s/saksman/DeepFish/data/Segmentation/Segmentation/domain_adaptation/target/target.csv", "r") as f:
    data = f.read().split('\n')
    data = numpy.array(data)  #convert array to numpy type array
    x_train, x_val = train_test_split(data, test_size=0.42)  

pd.DataFrame(x_train).to_csv("/global/u2/s/saksman/DeepFish/data/Segmentation/Segmentation/domain_adaptation/target/target_train.csv", index = False)
pd.DataFrame(x_val).to_csv("/global/u2/s/saksman/DeepFish/data/Segmentation/Segmentation/domain_adaptation/target/target_val.csv", index = False)
# manually: write header, remote quotes, remote /valid and /empty strings, move files around

# %%
# Test domain adaptation with all domain shift samples, 30 epochs
# !python trainval.py -e seg -sb ./results/domain_adaptation/da_ne30 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss None -n 310 -ne 30
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/da_ne30/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:20<00:00,  1.13s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.33it/s]
# 0 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 4 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# Test wihtout domain adaptation with all domain shift samples, 30 epochs
# !python trainval.py -e seg -sb ./results/domain_adaptation/noda_ne30 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss None -n 310 -ne 30
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/noda_ne30/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.75it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.37it/s]
# 0 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 4 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# Exp 2: Test domain adaptation with all samples, 10 epochs, domain shift dataset
# !python trainval.py -e seg -sb ./results/domain_adaptation/da_ne10 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss None -n 310 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/da_ne10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:20<00:00,  1.13s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.30it/s]
# 0 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 4 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# Test domain adaptation with all samples, 10 epochs, domain shift dataset
# !python trainval.py -e seg -sb ./results/domain_adaptation/da_ne10 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss None -n 310 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/da_ne10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:19<00:00,  1.12s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.47it/s]
# 0 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 4 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# Exp 2: Test no domain adaptation with all samples, 10 epochs, domain shift dataset
# !python trainval.py -e seg -sb ./results/domain_adaptation/noda_ne10 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss None -n 310 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/noda_ne10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.79it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.42it/s]
# 0 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 4 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# Test no domain adaptation with all samples, 10 epochs, domain shift dataset
# !python trainval.py -e seg -sb ./results/domain_adaptation/noda_ne10 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss None -n 310 -ne 10
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/noda_ne10/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.76it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.35it/s]
# 0 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 4 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# Test domain adaptation with all samples, 15 epochs, domain shift dataset
# !python trainval.py -e seg -sb ./results/domain_adaptation/da_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss None -n 310 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/da_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:27<00:00,  1.23s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.24it/s]
# 0 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 4 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# Test no domain adaptation with all samples, 15 epochs, domain shift dataset
# !python trainval.py -e seg -sb ./results/domain_adaptation/noda_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss None -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/noda_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:20<00:00,  3.46it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.23it/s]
# 0 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 4 - visualizing target_val image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# Test domain adaptation with all samples, 20 epochs, domain shift dataset
# !python trainval.py -e seg -sb ./results/domain_adaptation/da_ne20 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss None -n 310 -ne 20
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/da_ne20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:26<00:00,  1.22s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.39it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.001171      0.504346
# Saved in /global/u2/s/saksman/DeepFish/results/domain_adaptation/da_ne20/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:25<00:00,  1.20s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.26it/s]
# ...

# %%
# Test no domain adaptation with all samples, 20 epochs, domain shift dataset
# !python trainval.py -e seg -sb ./results/domain_adaptation/noda_ne20 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss None -n 310 -ne 20
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/domain_adaptation/noda_ne20/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:20<00:00,  3.47it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.25it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005185      0.453882
# Saved in /global/u2/s/saksman/DeepFish/results/domain_adaptation/noda_ne20/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:19<00:00,  3.68it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.42it/s]
# ...

# %% [markdown]
# ## Plot results across experiments

# %%
import matplotlib.pyplot as plt
no_da = {
0: 0, 
5: 0.454, 
10: 0.476, 
15: 0.399,
20: 0.47}
no_da_list = sorted(no_da.items()) # sorted by key, return a list of tuples

da = {
0: 0, 
5: 0.561, 
10: 0.579, 
15: 0.565,
20: 0.536}
da_list = sorted(da.items()) # sorted by key, return a list of tuples

plt.clf()
x1, y1 = zip(*no_da_list) # unpack a list of pairs into two tuples
x2, y2 = zip(*da_list) # unpack a list of pairs into two tuples
# plt.ylim(0, 100)
plt.plot(x1, y1, '--ro', label="Source-Only")
plt.plot(x2, y2, '--yo', label="Source + Unsupervised DA (AdaptSegNet)")
plt.legend(loc='lower right')
plt.title('')
plt.xlabel('Total # Epochs per Experiment')
plt.ylabel('Validation mIoU')
plt.savefig('/global/u2/s/saksman/DeepFish/results/domain_adaptation/perf_plot.png')
plt.show()

# %% [markdown]
# # Active Domain Adapation

# %% [markdown]
# ## Active learning v. fine-tuning experiments

# %% [markdown]
# ### Random Fine-tuning

# %%
# Random fine-tuning, 10 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n10_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 10 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.80it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.44it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005168      0.454227
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.06it/s]
# Validating
# ...

# %%
# Random fine-tuning, 10 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n10_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 10 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:19<00:00,  3.67it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:09<00:00,  4.20it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005188      0.454043
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.05it/s]
# Validating
# ...

# %%
# Random fine-tuning, 10 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n10_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 10 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.77it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.36it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005185      0.454251
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.92it/s]
# Validating
# ...

# %%
# Random fine-tuning, 20 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n20_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 20 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.78it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.45it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005196      0.453956
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.05it/s]
# Validating
# ...

# %%
# Random fine-tuning, 20 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n20_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 20 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:19<00:00,  3.72it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.38it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005198      0.453975
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.05it/s]
# Validating
# ...

# %%
# Random fine-tuning, 20 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n20_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 20 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.75it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:09<00:00,  4.21it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005184      0.453061
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.02it/s]
# Validating
# ...

# %%
# Random fine-tuning, 40 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n40_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 40 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n40_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  40
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.79it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.47it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005175      0.453302
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n40_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.06it/s]
# Validating
# ...

# %%
# Random fine-tuning, 40 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n40_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 40 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n40_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  40
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:19<00:00,  3.65it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.31it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005182      0.453834
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n40_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.04it/s]
# Validating
# ...

# %%
# Random fine-tuning, 40 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n40_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 40 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n40_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  40
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:19<00:00,  3.74it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.32it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005174      0.453705
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n40_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.01it/s]
# Validating
# ...

# %%
# Random fine-tuning, 80 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n80_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 80 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.80it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.46it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005225       0.45434
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.05it/s]
# Validating
# ...

# %%
# Random fine-tuning, 80 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n80_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 80 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.76it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:09<00:00,  4.09it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005167      0.453262
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.04it/s]
# Validating
# ...

# %%
# Random fine-tuning, 80 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n80_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 80 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:18<00:00,  3.75it/s]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.33it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.005228      0.454428
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_ft_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [00:17<00:00,  4.03it/s]
# Validating
# ...

# %%
# Random fine-tuning, 80 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_ft_n80_ne15 -d ./data/Segmentation/ -r 1 -da 0 -ds 1 -ss random -n 80 -ne 15
# Out:
# ^C
# Traceback (most recent call last):
#   File "trainval.py", line 13, in <module>
#     from haven import haven_utils as hu
#   File "/global/homes/s/saksman/.local/cori/pytorch1.7.1-gpu/lib/python3.8/site-packages/haven/haven_utils/__init__.py", line 20, in <module>
#     from .. import haven_img as hi
#   File "/global/homes/s/saksman/.local/cori/pytorch1.7.1-gpu/lib/python3.8/site-packages/haven/haven_img.py", line 5, in <module>
#     from skimage.segmentation import mark_boundaries
#   File "/global/homes/s/saksman/.local/cori/pytorch1.7.1-gpu/lib/python3.8/site-packages/skimage/segmentation/__init__.py", line 3, in <module>
#     from .active_contour_model import active_contour
#   File "/global/homes/s/saksman/.local/cori/pytorch1.7.1-gpu/lib/python3.8/site-packages/skimage/segmentation/active_contour_model.py", line 4, in <module>
#     from ..filters import sobel
# ...

# %% [markdown]
# ### Random active domain adaptation

# %%
# Random active DA, 10 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_activeDA_n10_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss random -n 10 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_activeDA_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  10
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:20<00:00,  1.13s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.45it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.001171      0.505129
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_activeDA_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:18<00:00,  1.10s/it]
# ...

# %%
# Random active DA, 20 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_activeDA_n20_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss random -n 20 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_activeDA_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  20
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:18<00:00,  1.11s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.53it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.001169      0.504389
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_activeDA_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:17<00:00,  1.09s/it]
# ...

# %%
# Random active DA, 40 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_activeDA_n40_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss random -n 40 -ne 15

# %%
# Random active DA, 80 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/random_activeDA_n80_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss random -n 80 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_activeDA_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  random
# # samples:  80
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:20<00:00,  1.13s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.43it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.001172      0.504838
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/random_activeDA_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:17<00:00,  1.09s/it]
# ...

# %% [markdown]
# ### Active adversarial domain adaptation

# %%
# AADA, 10 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/aada_n10_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss aada -n 10 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/aada_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  aada
# # samples:  10
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:19<00:00,  1.12s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.45it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0             0.00117      0.504701
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/aada_n10_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:18<00:00,  1.11s/it]
# Validating
# ...

# %%
# AADA, 20 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/aada_n20_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss aada -n 20 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/aada_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  aada
# # samples:  20
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:19<00:00,  1.12s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.50it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.001168      0.504612
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/aada_n20_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:18<00:00,  1.11s/it]
# Validating
# ...

# %%
# AADA, 40 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/aada_n40_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss aada -n 40 -ne 15

# %%
# AADA, 80 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/aada_n80_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss aada -n 80 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/aada_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  aada
# # samples:  80
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:26<00:00,  1.22s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:08<00:00,  4.45it/s]
#    epoch  train_seg_nll_loss  val_seg_mIoU
# 0      0            0.001167      0.504111
# Saved in /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/aada_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:25<00:00,  1.20s/it]
# Validating
# ...

# %%
# AADA, 80 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/aada_n80_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss aada -n 80 -ne 15
# Out:
# Running 1 experiments
#
# ******
# Exp id: e3666ff88d51e5edbb790ff8af6d89e0
#
# Hyperparameters:
# ----------------
# {'batch_size': 2,
#  'dataset': 'fish_seg',
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/active_domain_adaptation/aada_n80_ne15/e3666ff88d51e5edbb790ff8af6d89e0
# ...
# Running on device: cuda
# The sampling strategy is:  aada
# # samples:  80
# Training
# 100%|███████████████████████████████████████████| 71/71 [01:21<00:00,  1.15s/it]
# Validating
# 100%|███████████████████████████████████████████| 38/38 [00:07<00:00,  5.28it/s]
# 0 - visualizing test image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 1 - visualizing test image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 2 - visualizing test image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# 3 - visualizing test image - savedir:e3666ff88d51e5edbb790ff8af6d89e0
# ...

# %%
# AADA, 80 labels, 15 epochs
# !python trainval.py -e seg -sb ./results/active_domain_adaptation/aada_n80_ne15 -d ./data/Segmentation/ -r 1 -da 1 -ds 1 -ss aada -n 80 -ne 15
