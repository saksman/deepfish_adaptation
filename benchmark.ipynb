# %%
# Replicates DeepFish benchmark results in 20 epochs
# !python trainval.py -e seg -sb ./results/ -d ./data/Segmentation/ -r 1 -da 0 -ss None -n 310 -ne 20
# Out:
# Running 1 experiments
#
# ******
# Exp id: 3cc3a2209864355f28be598297005d56
#
# Hyperparameters:
# ----------------
# {'batch_size': 1,
#  'dataset': 'fish_seg',
#  'max_epoch': 1000,
#  'model': 'fcn8',
#  'task': 'seg',
#  'transform': 'rgb_normalize',
#  'wrapper': 'seg_wrapper'}
#
# Save directory: /global/u2/s/saksman/DeepFish/results/3cc3a2209864355f28be598297005d56
# ...
# Running on device: cuda
# 0 - visualizing val image - savedir:3cc3a2209864355f28be598297005d56
# 1 - visualizing val image - savedir:3cc3a2209864355f28be598297005d56
# 2 - visualizing val image - savedir:3cc3a2209864355f28be598297005d56
# 3 - visualizing val image - savedir:3cc3a2209864355f28be598297005d56
# 4 - visualizing val image - savedir:3cc3a2209864355f28be598297005d56
# Validating
# 100%|█████████████████████████████████████████| 124/124 [00:11<00:00, 10.35it/s]
# Training
# 100%|█████████████████████████████████████████| 310/310 [00:54<00:00,  5.73it/s]
#    epoch  val_seg_mIoU  train_seg_nll_loss
# ...
